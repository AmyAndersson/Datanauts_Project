# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as st
from scipy.stats import linregress
from pprint import pprint
from colorama import Fore
from colorama import Style
import datetime
import json
x = datetime.datetime.now()

# Automatically set Data Frames to 2 decimal places
pd.options.display.precision = 2

# Hide warning messages in notebook
import warnings
warnings.filterwarnings('ignore')

# print(x.strftime("%d""/""%m""/""%Y"))

from api_keys import api_key

# %%
days365=pd.Series(pd.date_range('2019', freq='D', periods=365)).dt.strftime("%Y-%m-%d")
days365
# Out:
# 0      2019-01-01
# 1      2019-01-02
# 2      2019-01-03
# 3      2019-01-04
# 4      2019-01-05
#           ...
# 360    2019-12-27
# 361    2019-12-28
# 362    2019-12-29
# 363    2019-12-30
# 364    2019-12-31
# Length: 365, dtype: object

# %%
DAYS= []
for days in days365:
    DAYS.append(str(days))
print(DAYS)
# Out:
# ['2019-01-01', '2019-01-02', '2019-01-03', '2019-01-04', '2019-01-05', '2019-01-06', '2019-01-07', '2019-01-08', '2019-01-09', '2019-01-10', '2019-01-11', '2019-01-12', '2019-01-13', '2019-01-14', '2019-01-15', '2019-01-16', '2019-01-17', '2019-01-18', '2019-01-19', '2019-01-20', '2019-01-21', '2019-01-22', '2019-01-23', '2019-01-24', '2019-01-25', '2019-01-26', '2019-01-27', '2019-01-28', '2019-01-29', '2019-01-30', '2019-01-31', '2019-02-01', '2019-02-02', '2019-02-03', '2019-02-04', '2019-02-05', '2019-02-06', '2019-02-07', '2019-02-08', '2019-02-09', '2019-02-10', '2019-02-11', '2019-02-12', '2019-02-13', '2019-02-14', '2019-02-15', '2019-02-16', '2019-02-17', '2019-02-18', '2019-02-19', '2019-02-20', '2019-02-21', '2019-02-22', '2019-02-23', '2019-02-24', '2019-02-25', '2019-02-26', '2019-02-27', '2019-02-28', '2019-03-01', '2019-03-02', '2019-03-03', '2019-03-04', '2019-03-05', '2019-03-06', '2019-03-07', '2019-03-08', '2019-03-09', '2019-03-10', '2019-03-11', '2019-03-12', '20
# ...

# %%
# asteroid_id=[]
# name=[]
# asteroid_date=[]
# absolute_magnitude_h=[]
# diameter_max_km = []
# diameter_min_km =[]
# diameter_min_km = []
# is_potentially_hazardous_asteroid=[]
# miss_distance_km = []
# orbiting_body =[]

# days_

# for date in DAYS: 
#     url_1=(f"https://api.nasa.gov/neo/rest/v1/feed?start_date={date}&end_date={date}&api_key={api_key}")
#     response=requests.get(url_1).json()
    
#     inside=response["near_earth_objects"][date]
    
#     for i in inside:
#         asteroid_date.append(date)
#         asteroid_id.append(response["near_earth_objects"][date][0]['id'])

#         name.append(response["near_earth_objects"][date][0]['name'])

#         absolute_magnitude_h.append(response["near_earth_objects"][date][0]['absolute_magnitude_h'])

#         diameter_max_km.append(response["near_earth_objects"][date][0]['estimated_diameter']['kilometers']['estimated_diameter_max'])

#         diameter_min_km.append(response["near_earth_objects"][date][0]['estimated_diameter']['kilometers']['estimated_diameter_min'])

#         is_potentially_hazardous_asteroid.append(response["near_earth_objects"][date][0]['is_potentially_hazardous_asteroid'])

#         miss_distance_km.append(response["near_earth_objects"][date][0]['close_approach_data'][0]['miss_distance']['kilometers'])

#         orbiting_body.append(response["near_earth_objects"][date][0]['close_approach_data'][0]['orbiting_body'])
        
#     print("done...next day")
# Out:
# done...next day
# done...next day
# done...next day
# done...next day
# done...next day
# done...next day
# done...next day
# done...next day
# done...next day
# done...next day
# done...next day
# done...next day
# done...next day
# done...next day
# done...next day
# done...next day
# done...next day
# done...next day
# done...next day
# done...next day
# done...next day
# done...next day
# done...next day
# done...next day
# done...next day
# done...next day
# done...next day
# done...next day
# done...next day
# done...next day
# done...next day
# done...next day
# done...next day
# done...next day
# done...next day
# done...next day
# done...next day
# done...next day
# done...next day
# done...next day
# done...next day
# done...next day
# done...next day
# done...next day
# done...next day
# done...next day
# done...next day
# done...next day
# done...next day
# done...next day
# done...next day
# done...next day
# done...next day
# done...next day
# done...next day
# ...

# %%
asteroid_id=[]
name=[]
asteroid_date=[]
absolute_magnitude_h=[]
diameter_max_km = []
diameter_min_km =[]
diameter_min_km = []
is_potentially_hazardous_asteroid=[]
miss_distance_km = []
orbiting_body =[]
x=0



for date in DAYS: 
    url_1=(f"https://api.nasa.gov/neo/rest/v1/feed?start_date={date}&end_date={date}&api_key={api_key}")
    response=requests.get(url_1).json()
    
    
   

    inside=response["near_earth_objects"][date]

    try:
        for i in inside:
            inside2=inside[x]
            asteroid_date.append(date)
            asteroid_id.append(inside2['id'])


            name.append(inside2['name'])

            absolute_magnitude_h.append(inside2['absolute_magnitude_h'])

            diameter_max_km.append(inside2['estimated_diameter']['kilometers']['estimated_diameter_max'])

            diameter_min_km.append(inside2['estimated_diameter']['kilometers']['estimated_diameter_min'])
            is_potentially_hazardous_asteroid.append(inside2['is_potentially_hazardous_asteroid'])

            miss_distance_km.append(inside2['close_approach_data'][0]['miss_distance']['kilometers'])

            orbiting_body.append(inside2['close_approach_data'][0]['orbiting_body'])
            x=x+1
    except:
        print("End of data")
        
#     print("done...next day")
# Out:
# End of data
# End of data
# End of data
# End of data
# End of data
# End of data
# End of data
# End of data
# End of data
# End of data
# End of data
# End of data
# End of data
# End of data
# End of data
# End of data
# End of data
# End of data
# End of data
# End of data
# End of data
# End of data
# End of data
# End of data
# End of data
# End of data
# End of data
# End of data
# End of data
# End of data
# End of data
# End of data
# End of data
# End of data
# End of data
# End of data
# End of data
# End of data
# End of data
# End of data
# End of data
# End of data
# End of data
# End of data
# End of data
# End of data
# End of data
# End of data
# End of data
# End of data
# End of data
# End of data
# End of data
# End of data
# End of data
# End of data
# End of data
# End of data
# End of data
# End of data
# End of data
# End of data
# End of data
# End of data
# End of data
# End of data
# End of data
# End of data
# End of data
# End of data
# End of data
# ...

# %%
miss_distance_km
# Out:
# ['19108365.537910876',
#  '17987605.956517039',
#  '11440989.539558679',
#  '10220722.30201183',
#  '70335665.49439282',
#  '30334082.201681494',
#  '57213293.897598778',
#  '15971072.819859934',
#  '11440988.941167199',
#  '70335410.474903831',
#  '59204319.400637923',
#  '27179532.711095424',
#  '16961872.123970375',
#  '73074559.786508532',
#  '778964.965283904',
#  '8762262.089577202',
#  '73074589.930479337',
#  '34067315.822064179',
#  '3633925.677386123',
#  '23827272.10243399',
#  '13671060.560786946',
#  '55070748.969839057',
#  '48639607.029055401',
#  '51571457.90478235',
#  '51930566.514612686',
#  '130070.725390817',
#  '4070964.081238754',
#  '52067825.462536364',
#  '16921089.769916491',
#  '9477381.182229535']

# %%
#     url_1=(f"https://api.nasa.gov/neo/rest/v1/feed?start_date=2019-01-01&end_date=2019-01-01&api_key={api_key}")
#     response=requests.get(url_1).json()

# %%
# response["near_earth_objects"]["2019-01-01"]

# %%
df = pd.DataFrame({"Date": asteroid_date, "ID": asteroid_id, "Name": name, "Absolute Magnitude": absolute_magnitude_h, "Estimated Max Diameter": diameter_max_km, "Estimated Min Diameter": diameter_min_km, "Potentially Hazardous?": is_potentially_hazardous_asteroid, "Miss Distance (km)": miss_distance_km, "Orbiting Body": orbiting_body})
df.head()
# Out:
#          Date       ID         Name  Absolute Magnitude  \
# 0  2019-01-01  3837557    (2019 AN)                24.2
# 1  2019-01-01  3398654  (2007 YS56)                25.7
# 2  2019-01-01  3398652  (2007 YQ56)                19.9
# 3  2019-01-01  3837538   (2018 YV2)                24.2
# 4  2019-01-01  3771017   (2017 EV2)                20.8
#
#    Estimated Max Diameter  Estimated Min Diameter  Potentially Hazardous?  \
# 0                    0.09                    0.04                   False
# 1                    0.04                    0.02                   False
# 2                    0.62                    0.28                    True
# 3                    0.09                    0.04                   False
# 4                    0.41                    0.18                   False
#
#    Miss Distance (km) Orbiting Body
# 0  19108365.537910876         Earth
# 1  17987605.956517039         Earth
# 2  11440989.539558679         Earth
# ...

# %%
df.to_csv('Asteroid.csv', index = False)
