# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as st
from scipy.stats import linregress
from pprint import pprint
from colorama import Fore
from colorama import Style
import json
import datetime
from datetime import date, timedelta
d = datetime.datetime.now()

# Automatically set Data Frames to 2 decimal places
pd.options.display.precision = 2

# Hide warning messages in notebook
import warnings
warnings.filterwarnings('ignore')

# print(x.strftime("%d""/""%m""/""%Y"))

# Import API key
from config import nasa_api_key

# %%
# Set URL for API
url = "https://api.nasa.gov/neo/rest/v1/feed?"

# URL Format
# https://api.nasa.gov/neo/rest/v1/feed?start_date=START_DATE&end_date=END_DATE&api_key=API_KEY

# %%
# Create a Series of dates over the entire year 2019 and call it "days365"
days365=pd.Series(pd.date_range('2019', freq='D', periods=365)).dt.strftime("%Y-%m-%d")
days365

# Create a list of days from the days365 series, to be able to use these in URL calls
day_365_list = []
for days in days365:
    day_365_list.append(str(days))
    
# print(day_365_list)

# %%
# Make 1 API calls to NASA to pull JSON files for 01-01-2019 as a test, prior to pull data for the entire year 2019
test_date = "2019-01-01"

print("-----------------------------------")
print("Starting API Call - Retrieving Data")
print("-----------------------------------\n")

url = f"https://api.nasa.gov/neo/rest/v1/feed?start_date={test_date}&end_date={test_date}&api_key={nasa_api_key}"

print(f"Completed API call for {test_date}\n")

print("-----------------------------------")
print("Data Retrieval Finalised")
print("-----------------------------------")

# Store JSON Response
test_response = requests.get(url).json()
# Out:
# -----------------------------------
# Starting API Call - Retrieving Data
# -----------------------------------
#
# Completed API call for 2019-01-01
#
# -----------------------------------
# Data Retrieval Finalised
# -----------------------------------

# %%
# response = requests.get(query_url).json()
pprint(test_response)
# Out:
# {'element_count': 10,
#  'links': {'next': 'http://www.neowsapp.com/rest/v1/feed?start_date=2019-01-02&end_date=2019-01-02&detailed=false&api_key=LSe3vESzMhcKrbbeo77f9CFvnFj5YgJyxF6WReji',
#            'prev': 'http://www.neowsapp.com/rest/v1/feed?start_date=2018-12-31&end_date=2018-12-31&detailed=false&api_key=LSe3vESzMhcKrbbeo77f9CFvnFj5YgJyxF6WReji',
#            'self': 'http://www.neowsapp.com/rest/v1/feed?start_date=2019-01-01&end_date=2019-01-01&detailed=false&api_key=LSe3vESzMhcKrbbeo77f9CFvnFj5YgJyxF6WReji'},
#  'near_earth_objects': {'2019-01-01': [{'absolute_magnitude_h': 24.2,
#                                         'close_approach_data': [{'close_approach_date': '2019-01-01',
#                                                                  'close_approach_date_full': '2019-Jan-01 '
#                                                                                              '07:58',
#                                                                  'epoch_date_close_approach': 1546329480000,
#                                                                  'miss_distance': {'astronomical': '0.1277315348',
#                                                                                    'kilometers': '19108365.537910876',
#                                                                                    'lunar': '49.6875670372',
#                                                                                    'miles': '11873387.7689510488'},
#                                                                  'orbiting_body': 'Earth',
#                                                                  'relative_velocity': {'kilometers_per_hour': '30126.8775250368',
#                                                                                        'kilometers_per_second': '8.3685770903',
#                                                                                        'miles_per_hour': '18719.6700932652'}}],
#                                         'estimated_diameter': {'feet': {'estimated_diameter_max': 281.8545369825,
#                                                                         'estimated_diameter_min': 126.0491808919},
#                                                                'kilometers': {'estimated_diameter_max': 0.0859092601,
#                                                                               'estimated_diameter_min': 0.0384197891},
#                                                                'meters': {'estimated_diameter_max': 85.9092601232,
#                                                                           'estimated_diameter_min': 38.4197891064},
#                                                                'miles': {'estimated_diameter_max': 0.0533815229,
#                                                                          'estimated_diameter_min': 0.0238729428}},
#                                         'id': '3837557',
#                                         'is_potentially_hazardous_asteroid': False,
#                                         'is_sentry_object': False,
#                                         'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3837557?api_key=LSe3vESzMhcKrbbeo77f9CFvnFj5YgJyxF6WReji'},
#                                         'name': '(2019 AN)',
#                                         'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3837557',
#                                         'neo_reference_id': '3837557'},
#                                        {'absolute_magnitude_h': 25.7,
#                                         'close_approach_data': [{'close_approach_date': '2019-01-01',
#                                                                  'close_approach_date_full': '2019-Jan-01 '
#                                                                                              '16:32',
#                                                                  'epoch_date_close_approach': 1546360320000,
#                                                                  'miss_distance': {'astronomical': '0.1202397197',
#                                                                                    'kilometers': '17987605.956517039',
#                                                                                    'lunar': '46.7732509633',
#                                                                                    'miles': '11176980.0579275782'},
#                                                                  'orbiting_body': 'Earth',
#                                                                  'relative_velocity': {'kilometers_per_hour': '23260.0875998701',
#                                                                                        'kilometers_per_second': '6.4611354444',
#                                                                                        'miles_per_hour': '14452.9138755971'}}],
#                                         'estimated_diameter': {'feet': {'estimated_diameter_max': 141.2618956756,
#                                                                         'estimated_diameter_min': 63.1742402722},
#                                                                'kilometers': {'estimated_diameter_max': 0.0430566244,
#                                                                               'estimated_diameter_min': 0.0192555078},
#                                                                'meters': {'estimated_diameter_max': 43.0566244241,
#                                                                           'estimated_diameter_min': 19.2555078188},
#                                                                'miles': {'estimated_diameter_max': 0.0267541378,
#                                                                          'estimated_diameter_min': 0.0119648141}},
#                                         'id': '3398654',
#                                         'is_potentially_hazardous_asteroid': False,
#                                         'is_sentry_object': False,
#                                         'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3398654?api_key=LSe3vESzMhcKrbbeo77f9CFvnFj5YgJyxF6WReji'},
#                                         'name': '(2007 YS56)',
#                                         'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3398654',
#                                         'neo_reference_id': '3398654'},
#                                        {'absolute_magnitude_h': 19.9,
#                                         'close_approach_data': [{'close_approach_date': '2019-01-01',
#                                                                  'close_approach_date_full': '2019-Jan-01 '
#                                                                                              '22:06',
#                                                                  'epoch_date_close_approach': 1546380360000,
#                                                                  'miss_distance': {'astronomical': '0.0764782917',
#                                                                                    'kilometers': '11440989.539558679',
#                                                                                    'lunar': '29.7500554713',
#                                                                                    'miles': '7109101.2464766102'},
#                                                                  'orbiting_body': 'Earth',
#                                                                  'relative_velocity': {'kilometers_per_hour': '55546.1544811129',
#                                                                                        'kilometers_per_second': '15.4294873559',
#                                                                                        'miles_per_hour': '34514.2202663337'}}],
#                                         'estimated_diameter': {'feet': {'estimated_diameter_max': 2041.8556210042,
#                                                                         'estimated_diameter_min': 913.1455937611},
#                                                                'kilometers': {'estimated_diameter_max': 0.6223575734,
#                                                                               'estimated_diameter_min': 0.2783267681},
#                                                                'meters': {'estimated_diameter_max': 622.3575733667,
#                                                                           'estimated_diameter_min': 278.3267680719},
#                                                                'miles': {'estimated_diameter_max': 0.3867149477,
#                                                                          'estimated_diameter_min': 0.1729441822}},
#                                         'id': '3398652',
#                                         'is_potentially_hazardous_asteroid': True,
#                                         'is_sentry_object': False,
#                                         'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3398652?api_key=LSe3vESzMhcKrbbeo77f9CFvnFj5YgJyxF6WReji'},
#                                         'name': '(2007 YQ56)',
#                                         'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3398652',
#                                         'neo_reference_id': '3398652'},
#                                        {'absolute_magnitude_h': 24.2,
#                                         'close_approach_data': [{'close_approach_date': '2019-01-01',
#                                                                  'close_approach_date_full': '2019-Jan-01 '
#                                                                                              '18:32',
#                                                                  'epoch_date_close_approach': 1546367520000,
#                                                                  'miss_distance': {'astronomical': '0.068321309',
#                                                                                    'kilometers': '10220722.30201183',
#                                                                                    'lunar': '26.576989201',
#                                                                                    'miles': '6350862.345070054'},
#                                                                  'orbiting_body': 'Earth',
#                                                                  'relative_velocity': {'kilometers_per_hour': '42187.1483751174',
#                                                                                        'kilometers_per_second': '11.7186523264',
#                                                                                        'miles_per_hour': '26213.4533889723'}}],
#                                         'estimated_diameter': {'feet': {'estimated_diameter_max': 281.8545369825,
#                                                                         'estimated_diameter_min': 126.0491808919},
#                                                                'kilometers': {'estimated_diameter_max': 0.0859092601,
#                                                                               'estimated_diameter_min': 0.0384197891},
#                                                                'meters': {'estimated_diameter_max': 85.9092601232,
#                                                                           'estimated_diameter_min': 38.4197891064},
#                                                                'miles': {'estimated_diameter_max': 0.0533815229,
#                                                                          'estimated_diameter_min': 0.0238729428}},
#                                         'id': '3837538',
#                                         'is_potentially_hazardous_asteroid': False,
#                                         'is_sentry_object': False,
#                                         'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3837538?api_key=LSe3vESzMhcKrbbeo77f9CFvnFj5YgJyxF6WReji'},
#                                         'name': '(2018 YV2)',
#                                         'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3837538',
#                                         'neo_reference_id': '3837538'},
#                                        {'absolute_magnitude_h': 20.8,
#                                         'close_approach_data': [{'close_approach_date': '2019-01-01',
#                                                                  'close_approach_date_full': '2019-Jan-01 '
#                                                                                              '15:36',
#                                                                  'epoch_date_close_approach': 1546356960000,
#                                                                  'miss_distance': {'astronomical': '0.470164886',
#                                                                                    'kilometers': '70335665.49439282',
#                                                                                    'lunar': '182.894140654',
#                                                                                    'miles': '43704555.931028116'},
#                                                                  'orbiting_body': 'Earth',
#                                                                  'relative_velocity': {'kilometers_per_hour': '49112.9067944009',
#                                                                                        'kilometers_per_second': '13.6424741096',
#                                                                                        'miles_per_hour': '30516.8503356654'}}],
#                                         'estimated_diameter': {'feet': {'estimated_diameter_max': 1349.040630575,
#                                                                         'estimated_diameter_min': 603.309310875},
#                                                                'kilometers': {'estimated_diameter_max': 0.411187571,
#                                                                               'estimated_diameter_min': 0.1838886721},
#                                                                'meters': {'estimated_diameter_max': 411.1875710413,
#                                                                           'estimated_diameter_min': 183.8886720703},
#                                                                'miles': {'estimated_diameter_max': 0.2555000322,
#                                                                          'estimated_diameter_min': 0.1142630881}},
#                                         'id': '3771017',
#                                         'is_potentially_hazardous_asteroid': False,
#                                         'is_sentry_object': False,
#                                         'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3771017?api_key=LSe3vESzMhcKrbbeo77f9CFvnFj5YgJyxF6WReji'},
#                                         'name': '(2017 EV2)',
#                                         'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3771017',
#                                         'neo_reference_id': '3771017'},
#                                        {'absolute_magnitude_h': 24.2,
#                                         'close_approach_data': [{'close_approach_date': '2019-01-01',
#                                                                  'close_approach_date_full': '2019-Jan-01 '
#                                                                                              '18:38',
#                                                                  'epoch_date_close_approach': 1546367880000,
#                                                                  'miss_distance': {'astronomical': '0.2027708162',
#                                                                                    'kilometers': '30334082.201681494',
#                                                                                    'lunar': '78.8778475018',
#                                                                                    'miles': '18848724.6531488572'},
#                                                                  'orbiting_body': 'Earth',
#                                                                  'relative_velocity': {'kilometers_per_hour': '29441.4234867558',
#                                                                                        'kilometers_per_second': '8.1781731908',
#                                                                                        'miles_per_hour': '18293.7556104233'}}],
#                                         'estimated_diameter': {'feet': {'estimated_diameter_max': 281.8545369825,
#                                                                         'estimated_diameter_min': 126.0491808919},
#                                                                'kilometers': {'estimated_diameter_max': 0.0859092601,
#                                                                               'estimated_diameter_min': 0.0384197891},
#                                                                'meters': {'estimated_diameter_max': 85.9092601232,
#                                                                           'estimated_diameter_min': 38.4197891064},
#                                                                'miles': {'estimated_diameter_max': 0.0533815229,
#                                                                          'estimated_diameter_min': 0.0238729428}},
#                                         'id': '3837589',
#                                         'is_potentially_hazardous_asteroid': False,
#                                         'is_sentry_object': False,
#                                         'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3837589?api_key=LSe3vESzMhcKrbbeo77f9CFvnFj5YgJyxF6WReji'},
#                                         'name': '(2019 AO2)',
#                                         'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3837589',
#                                         'neo_reference_id': '3837589'},
#                                        {'absolute_magnitude_h': 22.9,
#                                         'close_approach_data': [{'close_approach_date': '2019-01-01',
#                                                                  'close_approach_date_full': '2019-Jan-01 '
#                                                                                              '15:09',
#                                                                  'epoch_date_close_approach': 1546355340000,
#                                                                  'miss_distance': {'astronomical': '0.3824472494',
#                                                                                    'kilometers': '57213293.897598778',
#                                                                                    'lunar': '148.7719800166',
#                                                                                    'miles': '35550692.3204600164'},
#                                                                  'orbiting_body': 'Earth',
#                                                                  'relative_velocity': {'kilometers_per_hour': '43435.0216912874',
#                                                                                        'kilometers_per_second': '12.0652838031',
#                                                                                        'miles_per_hour': '26988.8333392336'}}],
#                                         'estimated_diameter': {'feet': {'estimated_diameter_max': 512.8909429502,
#                                                                         'estimated_diameter_min': 229.3718026961},
#                                                                'kilometers': {'estimated_diameter_max': 0.1563291544,
#                                                                               'estimated_diameter_min': 0.0699125232},
#                                                                'meters': {'estimated_diameter_max': 156.3291544087,
#                                                                           'estimated_diameter_min': 69.9125232246},
#                                                                'miles': {'estimated_diameter_max': 0.097138403,
#                                                                          'estimated_diameter_min': 0.0434416145}},
#                                         'id': '3827572',
#                                         'is_potentially_hazardous_asteroid': False,
#                                         'is_sentry_object': False,
#                                         'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3827572?api_key=LSe3vESzMhcKrbbeo77f9CFvnFj5YgJyxF6WReji'},
#                                         'name': '(2018 RL4)',
#                                         'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3827572',
#                                         'neo_reference_id': '3827572'},
#                                        {'absolute_magnitude_h': 24.0,
#                                         'close_approach_data': [{'close_approach_date': '2019-01-01',
#                                                                  'close_approach_date_full': '2019-Jan-01 '
#                                                                                              '19:21',
#                                                                  'epoch_date_close_approach': 1546370460000,
#                                                                  'miss_distance': {'astronomical': '0.1067600282',
#                                                                                    'kilometers': '15971072.819859934',
#                                                                                    'lunar': '41.5296509698',
#                                                                                    'miles': '9923964.4699137292'},
#                                                                  'orbiting_body': 'Earth',
#                                                                  'relative_velocity': {'kilometers_per_hour': '19446.0250723439',
#                                                                                        'kilometers_per_second': '5.4016736312',
#                                                                                        'miles_per_hour': '12083.0037456461'}}],
#                                         'estimated_diameter': {'feet': {'estimated_diameter_max': 309.0473542854,
#                                                                         'estimated_diameter_min': 138.2101784897},
#                                                                'kilometers': {'estimated_diameter_max': 0.0941976306,
#                                                                               'estimated_diameter_min': 0.0421264611},
#                                                                'meters': {'estimated_diameter_max': 94.1976305719,
#                                                                           'estimated_diameter_min': 42.1264610556},
#                                                                'miles': {'estimated_diameter_max': 0.0585316759,
#                                                                          'estimated_diameter_min': 0.0261761612}},
#                                         'id': '3836889',
#                                         'is_potentially_hazardous_asteroid': False,
#                                         'is_sentry_object': False,
#                                         'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3836889?api_key=LSe3vESzMhcKrbbeo77f9CFvnFj5YgJyxF6WReji'},
#                                         'name': '(2018 XB4)',
#                                         'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3836889',
#                                         'neo_reference_id': '3836889'},
#                                        {'absolute_magnitude_h': 19.9,
#                                         'close_approach_data': [{'close_approach_date': '2019-01-01',
#                                                                  'close_approach_date_full': '2019-Jan-01 '
#                                                                                              '22:06',
#                                                                  'epoch_date_close_approach': 1546380360000,
#                                                                  'miss_distance': {'astronomical': '0.0764782877',
#                                                                                    'kilometers': '11440988.941167199',
#                                                                                    'lunar': '29.7500539153',
#                                                                                    'miles': '7109100.8746533862'},
#                                                                  'orbiting_body': 'Earth',
#                                                                  'relative_velocity': {'kilometers_per_hour': '55546.1570231003',
#                                                                                        'kilometers_per_second': '15.429488062',
#                                                                                        'miles_per_hour': '34514.2218458258'}}],
#                                         'estimated_diameter': {'feet': {'estimated_diameter_max': 2041.8556210042,
#                                                                         'estimated_diameter_min': 913.1455937611},
#                                                                'kilometers': {'estimated_diameter_max': 0.6223575734,
#                                                                               'estimated_diameter_min': 0.2783267681},
#                                                                'meters': {'estimated_diameter_max': 622.3575733667,
#                                                                           'estimated_diameter_min': 278.3267680719},
#                                                                'miles': {'estimated_diameter_max': 0.3867149477,
#                                                                          'estimated_diameter_min': 0.1729441822}},
#                                         'id': '2527715',
#                                         'is_potentially_hazardous_asteroid': True,
#                                         'is_sentry_object': False,
#                                         'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/2527715?api_key=LSe3vESzMhcKrbbeo77f9CFvnFj5YgJyxF6WReji'},
#                                         'name': '527715 (2007 YQ56)',
#                                         'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2527715',
#                                         'neo_reference_id': '2527715'},
#                                        {'absolute_magnitude_h': 20.9,
#                                         'close_approach_data': [{'close_approach_date': '2019-01-01',
#                                                                  'close_approach_date_full': '2019-Jan-01 '
#                                                                                              '15:36',
#                                                                  'epoch_date_close_approach': 1546356960000,
#                                                                  'miss_distance': {'astronomical': '0.4701631813',
#                                                                                    'kilometers': '70335410.474903831',
#                                                                                    'lunar': '182.8934775257',
#                                                                                    'miles': '43704397.4692656278'},
#                                                                  'orbiting_body': 'Earth',
#                                                                  'relative_velocity': {'kilometers_per_hour': '49112.652286251',
#                                                                                        'kilometers_per_second': '13.6424034128',
#                                                                                        'miles_per_hour': '30516.6921941986'}}],
#                                         'estimated_diameter': {'feet': {'estimated_diameter_max': 1288.3238004408,
#                                                                         'estimated_diameter_min': 576.1559189633},
#                                                                'kilometers': {'estimated_diameter_max': 0.3926810818,
#                                                                               'estimated_diameter_min': 0.1756123185},
#                                                                'meters': {'estimated_diameter_max': 392.6810818086,
#                                                                           'estimated_diameter_min': 175.6123184804},
#                                                                'miles': {'estimated_diameter_max': 0.2440006365,
#                                                                          'estimated_diameter_min': 0.1091204019}},
#                                         'id': '2539856',
#                                         'is_potentially_hazardous_asteroid': False,
#                                         'is_sentry_object': False,
#                                         'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/2539856?api_key=LSe3vESzMhcKrbbeo77f9CFvnFj5YgJyxF6WReji'},
#                                         'name': '539856 (2017 EV2)',
#                                         'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2539856',
#                                         'neo_reference_id': '2539856'}]}}

# %%
# Create lists to hold all of our information we want to store and analyse
asteroid_id=[]
asteroid_name=[]
asteroid_date = []
absolute_magnitude_h=[]
diameter_max_km = []
diameter_min_km = []
is_potentially_hazardous_asteroid=[]
miss_distance_km = []
orbiting_body =[]
relative_velocity =[]
close_approach_date=[]

# Create a counter to be able to change between asteriod dates
x = 0

# Make 365 API calls to NASA to pull JSON files for each date in 2019
print("--------------------------------------------------------------")
print("Starting API Call - Retrieving Data")
print("--------------------------------------------------------------")

for date in day_365_list:
    url = f"https://api.nasa.gov/neo/rest/v1/feed?start_date={date}&end_date={date}&api_key={nasa_api_key}"
    
# URL Format - url = f"https://api.nasa.gov/neo/rest/v1/feed?start_date=2019-01-01&end_date=2019-01-01&api_key={api_key}"

    # Store JSON Response
    response = requests.get(url).json()

    # Create a variable for each date in the JSON Response
    inside = response["near_earth_objects"][date]


# Try and loop through each date the JSON Response and store each element in lists, per asteroid
    try:
        for i in inside:
            
            # Create a variable to be able to loop through each asteriod
            each_asteroid = inside[x]
            
            # Append the asteroid date
            asteroid_date.append(date)
            
            # Append the asteroid ID
            asteroid_id.append(each_asteroid['id'])

            # Append the asteroid name
            asteroid_name.append(each_asteroid['name'])

            # Append the absolute magnitude
            absolute_magnitude_h.append(each_asteroid['absolute_magnitude_h'])

            # Append the max diameter
            diameter_max_km.append(each_asteroid['estimated_diameter']['kilometers']['estimated_diameter_max'])

            # Append the min diameter
            diameter_min_km.append(each_asteroid['estimated_diameter']['kilometers']['estimated_diameter_min'])
            
            # Append "True" or "False", based on whether or not the asteroid was peotentially hazardous
            is_potentially_hazardous_asteroid.append(each_asteroid['is_potentially_hazardous_asteroid'])

            # Append the miss distance 
            miss_distance_km.append(each_asteroid['close_approach_data'][0]['miss_distance']['kilometers'])

            # Append the orbiting body of the asteroid
            orbiting_body.append(each_asteroid['close_approach_data'][0]['orbiting_body'])
            
            # Append the asteroid relative velocity
            relative_velocity.append(each_asteroid['close_approach_data'][0]['relative_velocity']['kilometers_per_second'])
            
            # Append the date the asteroid was considered to be a NEO (Near Earth Object)
            close_approach_date.append(each_asteroid['close_approach_data'][0]["close_approach_date"])
            
            # Move to the next asteroid
            x = x + 1
            
    except:
        print("End of data")
    
    # Reset the asteroid to the first asteroid of the next date
    x = 0   
    
    print(f"Completed API call for {date}, continuing to the next date")
    
print("--------------------------------------------------------------")
print("Data Retrieval Finalised")
print("--------------------------------------------------------------")
# Out:
# --------------------------------------------------------------
# Starting API Call - Retrieving Data
# --------------------------------------------------------------
# Completed API call for 2019-01-01, continuing to the next date
# Completed API call for 2019-01-02, continuing to the next date
# Completed API call for 2019-01-03, continuing to the next date
# Completed API call for 2019-01-04, continuing to the next date
# Completed API call for 2019-01-05, continuing to the next date
# Completed API call for 2019-01-06, continuing to the next date
# Completed API call for 2019-01-07, continuing to the next date
# Completed API call for 2019-01-08, continuing to the next date
# Completed API call for 2019-01-09, continuing to the next date
# Completed API call for 2019-01-10, continuing to the next date
# Completed API call for 2019-01-11, continuing to the next date
# Completed API call for 2019-01-12, continuing to the next date
# Completed API call for 2019-01-13, continuing to the next date
# Completed API call for 2019-01-14, continuing to the next date
# Completed API call for 2019-01-15, continuing to the next date
# Completed API call for 2019-01-16, continuing to the next date
# Completed API call for 2019-01-17, continuing to the next date
# Completed API call for 2019-01-18, continuing to the next date
# Completed API call for 2019-01-19, continuing to the next date
# Completed API call for 2019-01-20, continuing to the next date
# Completed API call for 2019-01-21, continuing to the next date
# Completed API call for 2019-01-22, continuing to the next date
# Completed API call for 2019-01-23, continuing to the next date
# Completed API call for 2019-01-24, continuing to the next date
# Completed API call for 2019-01-25, continuing to the next date
# Completed API call for 2019-01-26, continuing to the next date
# Completed API call for 2019-01-27, continuing to the next date
# Completed API call for 2019-01-28, continuing to the next date
# Completed API call for 2019-01-29, continuing to the next date
# Completed API call for 2019-01-30, continuing to the next date
# Completed API call for 2019-01-31, continuing to the next date
# Completed API call for 2019-02-01, continuing to the next date
# Completed API call for 2019-02-02, continuing to the next date
# Completed API call for 2019-02-03, continuing to the next date
# Completed API call for 2019-02-04, continuing to the next date
# Completed API call for 2019-02-05, continuing to the next date
# Completed API call for 2019-02-06, continuing to the next date
# Completed API call for 2019-02-07, continuing to the next date
# Completed API call for 2019-02-08, continuing to the next date
# Completed API call for 2019-02-09, continuing to the next date
# Completed API call for 2019-02-10, continuing to the next date
# Completed API call for 2019-02-11, continuing to the next date
# Completed API call for 2019-02-12, continuing to the next date
# Completed API call for 2019-02-13, continuing to the next date
# Completed API call for 2019-02-14, continuing to the next date
# Completed API call for 2019-02-15, continuing to the next date
# Completed API call for 2019-02-16, continuing to the next date
# Completed API call for 2019-02-17, continuing to the next date
# Completed API call for 2019-02-18, continuing to the next date
# Completed API call for 2019-02-19, continuing to the next date
# Completed API call for 2019-02-20, continuing to the next date
# Completed API call for 2019-02-21, continuing to the next date
# Completed API call for 2019-02-22, continuing to the next date
# Completed API call for 2019-02-23, continuing to the next date
# Completed API call for 2019-02-24, continuing to the next date
# Completed API call for 2019-02-25, continuing to the next date
# Completed API call for 2019-02-26, continuing to the next date
# Completed API call for 2019-02-27, continuing to the next date
# Completed API call for 2019-02-28, continuing to the next date
# Completed API call for 2019-03-01, continuing to the next date
# Completed API call for 2019-03-02, continuing to the next date
# Completed API call for 2019-03-03, continuing to the next date
# Completed API call for 2019-03-04, continuing to the next date
# Completed API call for 2019-03-05, continuing to the next date
# Completed API call for 2019-03-06, continuing to the next date
# Completed API call for 2019-03-07, continuing to the next date
# Completed API call for 2019-03-08, continuing to the next date
# Completed API call for 2019-03-09, continuing to the next date
# Completed API call for 2019-03-10, continuing to the next date
# Completed API call for 2019-03-11, continuing to the next date
# Completed API call for 2019-03-12, continuing to the next date
# Completed API call for 2019-03-13, continuing to the next date
# Completed API call for 2019-03-14, continuing to the next date
# Completed API call for 2019-03-15, continuing to the next date
# Completed API call for 2019-03-16, continuing to the next date
# Completed API call for 2019-03-17, continuing to the next date
# Completed API call for 2019-03-18, continuing to the next date
# Completed API call for 2019-03-19, continuing to the next date
# Completed API call for 2019-03-20, continuing to the next date
# Completed API call for 2019-03-21, continuing to the next date
# Completed API call for 2019-03-22, continuing to the next date
# Completed API call for 2019-03-23, continuing to the next date
# Completed API call for 2019-03-24, continuing to the next date
# Completed API call for 2019-03-25, continuing to the next date
# Completed API call for 2019-03-26, continuing to the next date
# Completed API call for 2019-03-27, continuing to the next date
# Completed API call for 2019-03-28, continuing to the next date
# Completed API call for 2019-03-29, continuing to the next date
# Completed API call for 2019-03-30, continuing to the next date
# Completed API call for 2019-03-31, continuing to the next date
# Completed API call for 2019-04-01, continuing to the next date
# Completed API call for 2019-04-02, continuing to the next date
# Completed API call for 2019-04-03, continuing to the next date
# Completed API call for 2019-04-04, continuing to the next date
# Completed API call for 2019-04-05, continuing to the next date
# Completed API call for 2019-04-06, continuing to the next date
# Completed API call for 2019-04-07, continuing to the next date
# Completed API call for 2019-04-08, continuing to the next date
# Completed API call for 2019-04-09, continuing to the next date
# Completed API call for 2019-04-10, continuing to the next date
# Completed API call for 2019-04-11, continuing to the next date
# Completed API call for 2019-04-12, continuing to the next date
# Completed API call for 2019-04-13, continuing to the next date
# Completed API call for 2019-04-14, continuing to the next date
# Completed API call for 2019-04-15, continuing to the next date
# Completed API call for 2019-04-16, continuing to the next date
# Completed API call for 2019-04-17, continuing to the next date
# Completed API call for 2019-04-18, continuing to the next date
# Completed API call for 2019-04-19, continuing to the next date
# Completed API call for 2019-04-20, continuing to the next date
# Completed API call for 2019-04-21, continuing to the next date
# Completed API call for 2019-04-22, continuing to the next date
# Completed API call for 2019-04-23, continuing to the next date
# Completed API call for 2019-04-24, continuing to the next date
# Completed API call for 2019-04-25, continuing to the next date
# Completed API call for 2019-04-26, continuing to the next date
# Completed API call for 2019-04-27, continuing to the next date
# Completed API call for 2019-04-28, continuing to the next date
# Completed API call for 2019-04-29, continuing to the next date
# Completed API call for 2019-04-30, continuing to the next date
# Completed API call for 2019-05-01, continuing to the next date
# Completed API call for 2019-05-02, continuing to the next date
# Completed API call for 2019-05-03, continuing to the next date
# Completed API call for 2019-05-04, continuing to the next date
# Completed API call for 2019-05-05, continuing to the next date
# Completed API call for 2019-05-06, continuing to the next date
# Completed API call for 2019-05-07, continuing to the next date
# Completed API call for 2019-05-08, continuing to the next date
# Completed API call for 2019-05-09, continuing to the next date
# Completed API call for 2019-05-10, continuing to the next date
# Completed API call for 2019-05-11, continuing to the next date
# Completed API call for 2019-05-12, continuing to the next date
# Completed API call for 2019-05-13, continuing to the next date
# Completed API call for 2019-05-14, continuing to the next date
# Completed API call for 2019-05-15, continuing to the next date
# Completed API call for 2019-05-16, continuing to the next date
# Completed API call for 2019-05-17, continuing to the next date
# Completed API call for 2019-05-18, continuing to the next date
# Completed API call for 2019-05-19, continuing to the next date
# Completed API call for 2019-05-20, continuing to the next date
# Completed API call for 2019-05-21, continuing to the next date
# Completed API call for 2019-05-22, continuing to the next date
# Completed API call for 2019-05-23, continuing to the next date
# Completed API call for 2019-05-24, continuing to the next date
# Completed API call for 2019-05-25, continuing to the next date
# Completed API call for 2019-05-26, continuing to the next date
# Completed API call for 2019-05-27, continuing to the next date
# Completed API call for 2019-05-28, continuing to the next date
# Completed API call for 2019-05-29, continuing to the next date
# Completed API call for 2019-05-30, continuing to the next date
# Completed API call for 2019-05-31, continuing to the next date
# Completed API call for 2019-06-01, continuing to the next date
# Completed API call for 2019-06-02, continuing to the next date
# Completed API call for 2019-06-03, continuing to the next date
# Completed API call for 2019-06-04, continuing to the next date
# Completed API call for 2019-06-05, continuing to the next date
# Completed API call for 2019-06-06, continuing to the next date
# Completed API call for 2019-06-07, continuing to the next date
# Completed API call for 2019-06-08, continuing to the next date
# Completed API call for 2019-06-09, continuing to the next date
# Completed API call for 2019-06-10, continuing to the next date
# Completed API call for 2019-06-11, continuing to the next date
# Completed API call for 2019-06-12, continuing to the next date
# Completed API call for 2019-06-13, continuing to the next date
# Completed API call for 2019-06-14, continuing to the next date
# Completed API call for 2019-06-15, continuing to the next date
# Completed API call for 2019-06-16, continuing to the next date
# Completed API call for 2019-06-17, continuing to the next date
# Completed API call for 2019-06-18, continuing to the next date
# Completed API call for 2019-06-19, continuing to the next date
# Completed API call for 2019-06-20, continuing to the next date
# Completed API call for 2019-06-21, continuing to the next date
# Completed API call for 2019-06-22, continuing to the next date
# Completed API call for 2019-06-23, continuing to the next date
# Completed API call for 2019-06-24, continuing to the next date
# Completed API call for 2019-06-25, continuing to the next date
# Completed API call for 2019-06-26, continuing to the next date
# Completed API call for 2019-06-27, continuing to the next date
# Completed API call for 2019-06-28, continuing to the next date
# Completed API call for 2019-06-29, continuing to the next date
# Completed API call for 2019-06-30, continuing to the next date
# Completed API call for 2019-07-01, continuing to the next date
# Completed API call for 2019-07-02, continuing to the next date
# Completed API call for 2019-07-03, continuing to the next date
# Completed API call for 2019-07-04, continuing to the next date
# Completed API call for 2019-07-05, continuing to the next date
# Completed API call for 2019-07-06, continuing to the next date
# Completed API call for 2019-07-07, continuing to the next date
# Completed API call for 2019-07-08, continuing to the next date
# Completed API call for 2019-07-09, continuing to the next date
# Completed API call for 2019-07-10, continuing to the next date
# Completed API call for 2019-07-11, continuing to the next date
# Completed API call for 2019-07-12, continuing to the next date
# Completed API call for 2019-07-13, continuing to the next date
# Completed API call for 2019-07-14, continuing to the next date
# Completed API call for 2019-07-15, continuing to the next date
# Completed API call for 2019-07-16, continuing to the next date
# Completed API call for 2019-07-17, continuing to the next date
# Completed API call for 2019-07-18, continuing to the next date
# Completed API call for 2019-07-19, continuing to the next date
# Completed API call for 2019-07-20, continuing to the next date
# Completed API call for 2019-07-21, continuing to the next date
# Completed API call for 2019-07-22, continuing to the next date
# Completed API call for 2019-07-23, continuing to the next date
# Completed API call for 2019-07-24, continuing to the next date
# Completed API call for 2019-07-25, continuing to the next date
# Completed API call for 2019-07-26, continuing to the next date
# Completed API call for 2019-07-27, continuing to the next date
# Completed API call for 2019-07-28, continuing to the next date
# Completed API call for 2019-07-29, continuing to the next date
# Completed API call for 2019-07-30, continuing to the next date
# Completed API call for 2019-07-31, continuing to the next date
# Completed API call for 2019-08-01, continuing to the next date
# Completed API call for 2019-08-02, continuing to the next date
# Completed API call for 2019-08-03, continuing to the next date
# Completed API call for 2019-08-04, continuing to the next date
# Completed API call for 2019-08-05, continuing to the next date
# Completed API call for 2019-08-06, continuing to the next date
# Completed API call for 2019-08-07, continuing to the next date
# Completed API call for 2019-08-08, continuing to the next date
# Completed API call for 2019-08-09, continuing to the next date
# Completed API call for 2019-08-10, continuing to the next date
# Completed API call for 2019-08-11, continuing to the next date
# Completed API call for 2019-08-12, continuing to the next date
# Completed API call for 2019-08-13, continuing to the next date
# Completed API call for 2019-08-14, continuing to the next date
# Completed API call for 2019-08-15, continuing to the next date
# Completed API call for 2019-08-16, continuing to the next date
# Completed API call for 2019-08-17, continuing to the next date
# Completed API call for 2019-08-18, continuing to the next date
# Completed API call for 2019-08-19, continuing to the next date
# Completed API call for 2019-08-20, continuing to the next date
# Completed API call for 2019-08-21, continuing to the next date
# Completed API call for 2019-08-22, continuing to the next date
# Completed API call for 2019-08-23, continuing to the next date
# Completed API call for 2019-08-24, continuing to the next date
# Completed API call for 2019-08-25, continuing to the next date
# Completed API call for 2019-08-26, continuing to the next date
# Completed API call for 2019-08-27, continuing to the next date
# Completed API call for 2019-08-28, continuing to the next date
# Completed API call for 2019-08-29, continuing to the next date
# Completed API call for 2019-08-30, continuing to the next date
# Completed API call for 2019-08-31, continuing to the next date
# Completed API call for 2019-09-01, continuing to the next date
# Completed API call for 2019-09-02, continuing to the next date
# Completed API call for 2019-09-03, continuing to the next date
# Completed API call for 2019-09-04, continuing to the next date
# Completed API call for 2019-09-05, continuing to the next date
# Completed API call for 2019-09-06, continuing to the next date
# Completed API call for 2019-09-07, continuing to the next date
# Completed API call for 2019-09-08, continuing to the next date
# Completed API call for 2019-09-09, continuing to the next date
# Completed API call for 2019-09-10, continuing to the next date
# Completed API call for 2019-09-11, continuing to the next date
# Completed API call for 2019-09-12, continuing to the next date
# Completed API call for 2019-09-13, continuing to the next date
# Completed API call for 2019-09-14, continuing to the next date
# Completed API call for 2019-09-15, continuing to the next date
# Completed API call for 2019-09-16, continuing to the next date
# Completed API call for 2019-09-17, continuing to the next date
# Completed API call for 2019-09-18, continuing to the next date
# Completed API call for 2019-09-19, continuing to the next date
# Completed API call for 2019-09-20, continuing to the next date
# Completed API call for 2019-09-21, continuing to the next date
# Completed API call for 2019-09-22, continuing to the next date
# Completed API call for 2019-09-23, continuing to the next date
# Completed API call for 2019-09-24, continuing to the next date
# Completed API call for 2019-09-25, continuing to the next date
# Completed API call for 2019-09-26, continuing to the next date
# Completed API call for 2019-09-27, continuing to the next date
# Completed API call for 2019-09-28, continuing to the next date
# Completed API call for 2019-09-29, continuing to the next date
# Completed API call for 2019-09-30, continuing to the next date
# Completed API call for 2019-10-01, continuing to the next date
# Completed API call for 2019-10-02, continuing to the next date
# Completed API call for 2019-10-03, continuing to the next date
# Completed API call for 2019-10-04, continuing to the next date
# Completed API call for 2019-10-05, continuing to the next date
# Completed API call for 2019-10-06, continuing to the next date
# Completed API call for 2019-10-07, continuing to the next date
# Completed API call for 2019-10-08, continuing to the next date
# Completed API call for 2019-10-09, continuing to the next date
# Completed API call for 2019-10-10, continuing to the next date
# Completed API call for 2019-10-11, continuing to the next date
# Completed API call for 2019-10-12, continuing to the next date
# Completed API call for 2019-10-13, continuing to the next date
# Completed API call for 2019-10-14, continuing to the next date
# Completed API call for 2019-10-15, continuing to the next date
# Completed API call for 2019-10-16, continuing to the next date
# Completed API call for 2019-10-17, continuing to the next date
# Completed API call for 2019-10-18, continuing to the next date
# Completed API call for 2019-10-19, continuing to the next date
# Completed API call for 2019-10-20, continuing to the next date
# Completed API call for 2019-10-21, continuing to the next date
# Completed API call for 2019-10-22, continuing to the next date
# Completed API call for 2019-10-23, continuing to the next date
# Completed API call for 2019-10-24, continuing to the next date
# Completed API call for 2019-10-25, continuing to the next date
# Completed API call for 2019-10-26, continuing to the next date
# Completed API call for 2019-10-27, continuing to the next date
# Completed API call for 2019-10-28, continuing to the next date
# Completed API call for 2019-10-29, continuing to the next date
# Completed API call for 2019-10-30, continuing to the next date
# Completed API call for 2019-10-31, continuing to the next date
# Completed API call for 2019-11-01, continuing to the next date
# Completed API call for 2019-11-02, continuing to the next date
# Completed API call for 2019-11-03, continuing to the next date
# Completed API call for 2019-11-04, continuing to the next date
# Completed API call for 2019-11-05, continuing to the next date
# Completed API call for 2019-11-06, continuing to the next date
# Completed API call for 2019-11-07, continuing to the next date
# Completed API call for 2019-11-08, continuing to the next date
# Completed API call for 2019-11-09, continuing to the next date
# Completed API call for 2019-11-10, continuing to the next date
# Completed API call for 2019-11-11, continuing to the next date
# Completed API call for 2019-11-12, continuing to the next date
# Completed API call for 2019-11-13, continuing to the next date
# Completed API call for 2019-11-14, continuing to the next date
# Completed API call for 2019-11-15, continuing to the next date
# Completed API call for 2019-11-16, continuing to the next date
# Completed API call for 2019-11-17, continuing to the next date
# Completed API call for 2019-11-18, continuing to the next date
# Completed API call for 2019-11-19, continuing to the next date
# Completed API call for 2019-11-20, continuing to the next date
# Completed API call for 2019-11-21, continuing to the next date
# Completed API call for 2019-11-22, continuing to the next date
# Completed API call for 2019-11-23, continuing to the next date
# Completed API call for 2019-11-24, continuing to the next date
# Completed API call for 2019-11-25, continuing to the next date
# Completed API call for 2019-11-26, continuing to the next date
# Completed API call for 2019-11-27, continuing to the next date
# Completed API call for 2019-11-28, continuing to the next date
# Completed API call for 2019-11-29, continuing to the next date
# Completed API call for 2019-11-30, continuing to the next date
# Completed API call for 2019-12-01, continuing to the next date
# Completed API call for 2019-12-02, continuing to the next date
# Completed API call for 2019-12-03, continuing to the next date
# Completed API call for 2019-12-04, continuing to the next date
# Completed API call for 2019-12-05, continuing to the next date
# Completed API call for 2019-12-06, continuing to the next date
# Completed API call for 2019-12-07, continuing to the next date
# Completed API call for 2019-12-08, continuing to the next date
# Completed API call for 2019-12-09, continuing to the next date
# Completed API call for 2019-12-10, continuing to the next date
# Completed API call for 2019-12-11, continuing to the next date
# Completed API call for 2019-12-12, continuing to the next date
# Completed API call for 2019-12-13, continuing to the next date
# Completed API call for 2019-12-14, continuing to the next date
# Completed API call for 2019-12-15, continuing to the next date
# Completed API call for 2019-12-16, continuing to the next date
# Completed API call for 2019-12-17, continuing to the next date
# Completed API call for 2019-12-18, continuing to the next date
# Completed API call for 2019-12-19, continuing to the next date
# Completed API call for 2019-12-20, continuing to the next date
# Completed API call for 2019-12-21, continuing to the next date
# Completed API call for 2019-12-22, continuing to the next date
# Completed API call for 2019-12-23, continuing to the next date
# Completed API call for 2019-12-24, continuing to the next date
# Completed API call for 2019-12-25, continuing to the next date
# Completed API call for 2019-12-26, continuing to the next date
# Completed API call for 2019-12-27, continuing to the next date
# Completed API call for 2019-12-28, continuing to the next date
# Completed API call for 2019-12-29, continuing to the next date
# Completed API call for 2019-12-30, continuing to the next date
# Completed API call for 2019-12-31, continuing to the next date
# --------------------------------------------------------------
# Data Retrieval Finalised
# --------------------------------------------------------------

# %%
# Put all data into a data frame
asteroid_df = pd.DataFrame({"Observed Date": asteroid_date, 
                            "Asteroid ID":asteroid_id, 
                            "Asteroid Name": asteroid_name, 
                            "Absolute Magnitude": absolute_magnitude_h, 
                            "Relative Velocity (k/s)" : relative_velocity, 
                            "Close Approach Date": close_approach_date, 
                            "Estimated Max Diameter (km)": diameter_max_km, 
                            "Estimated Min Diameter (km)": diameter_min_km, 
                            "Potentially Hazardous?": is_potentially_hazardous_asteroid, 
                            "Miss Distance (km)": miss_distance_km, 
                            "Orbiting Body": orbiting_body})

# Display head of data frame
asteroid_df.head()
# Out:
#   Observed Date Asteroid ID Asteroid Name  Absolute Magnitude  \
# 0    2019-01-01     3837557     (2019 AN)                24.2
# 1    2019-01-01     3398654   (2007 YS56)                25.7
# 2    2019-01-01     3398652   (2007 YQ56)                19.9
# 3    2019-01-01     3837538    (2018 YV2)                24.2
# 4    2019-01-01     3771017    (2017 EV2)                20.8
#
#   Relative Velocity (k/s) Close Approach Date  Estimated Max Diameter (km)  \
# 0            8.3685770903          2019-01-01                         0.09
# 1            6.4611354444          2019-01-01                         0.04
# 2           15.4294873559          2019-01-01                         0.62
# 3           11.7186523264          2019-01-01                         0.09
# 4           13.6424741096          2019-01-01                         0.41
#
#    Estimated Min Diameter (km)  Potentially Hazardous?  Miss Distance (km)  \
# 0                         0.04                   False  19108365.537910876
# 1                         0.02                   False  17987605.956517039
# 2                         0.28                    True  11440989.539558679
# 3                         0.04                   False   10220722.30201183
# 4                         0.18                   False   70335665.49439282
#
#   Orbiting Body
# 0         Earth
# 1         Earth
# 2         Earth
# 3         Earth
# 4         Earth

# %%
# Split Observed Date into year, month and day to enable use for further analysis 
asteroid_df["Year"] = pd.DatetimeIndex(asteroid_df["Observed Date"]).year
asteroid_df["Month"] = pd.DatetimeIndex(asteroid_df["Observed Date"]).month
asteroid_df["Day"] = pd.DatetimeIndex(asteroid_df["Observed Date"]).day

# View dataframe with new columns
asteroid_df
# Out:
#      Observed Date Asteroid ID         Asteroid Name  Absolute Magnitude  \
# 0       2019-01-01     3837557             (2019 AN)               24.20
# 1       2019-01-01     3398654           (2007 YS56)               25.70
# 2       2019-01-01     3398652           (2007 YQ56)               19.90
# 3       2019-01-01     3837538            (2018 YV2)               24.20
# 4       2019-01-01     3771017            (2017 EV2)               20.80
# ...            ...         ...                   ...                 ...
# 5047    2019-12-31     2006239  6239 Minos (1989 QF)               18.50
# 5048    2019-12-31     3555072            (2011 AH5)               26.00
# 5049    2019-12-31     3976544            (2020 AA2)               27.00
# 5050    2019-12-31     3893722            (2019 WR4)               26.07
# 5051    2019-12-31    54017302            (2020 KV6)               25.79
#
#      Relative Velocity (k/s) Close Approach Date  Estimated Max Diameter (km)  \
# 0               8.3685770903          2019-01-01                         0.09
# 1               6.4611354444          2019-01-01                         0.04
# 2              15.4294873559          2019-01-01                         0.62
# 3              11.7186523264          2019-01-01                         0.09
# 4              13.6424741096          2019-01-01                         0.41
# ...                      ...                 ...                          ...
# 5047            9.0074118926          2019-12-31                         1.19
# 5048           17.9801017354          2019-12-31                         0.04
# 5049             9.714685182          2019-12-31                         0.02
# 5050            4.2368173377          2019-12-31                         0.04
# 5051           12.5247240229          2019-12-31                         0.04
#
#       Estimated Min Diameter (km)  Potentially Hazardous?  Miss Distance (km)  \
# 0                            0.04                   False  19108365.537910876
# 1                            0.02                   False  17987605.956517039
# 2                            0.28                    True  11440989.539558679
# 3                            0.04                   False   10220722.30201183
# 4                            0.18                   False   70335665.49439282
# ...                           ...                     ...                 ...
# 5047                         0.53                    True  63468291.108281158
# 5048                         0.02                   False  43414047.649301524
# 5049                         0.01                   False   1643656.885252799
# 5050                         0.02                   False   4493434.883867377
# 5051                         0.02                   False  64500545.388388577
#
#      Orbiting Body  Year  Month  Day
# 0            Earth  2019      1    1
# 1            Earth  2019      1    1
# 2            Earth  2019      1    1
# 3            Earth  2019      1    1
# 4            Earth  2019      1    1
# ...            ...   ...    ...  ...
# 5047         Earth  2019     12   31
# 5048         Earth  2019     12   31
# 5049         Earth  2019     12   31
# 5050         Earth  2019     12   31
# 5051         Earth  2019     12   31
#
# [5052 rows x 14 columns]

# %%
# Export data frame to CSV
asteroid_df.to_csv('Asteroid.csv', index = False)
