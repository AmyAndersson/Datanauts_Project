# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as st
from scipy.stats import linregress
from pprint import pprint
from colorama import Fore
from colorama import Style
import datetime
import json
x = datetime.datetime.now()

# Automatically set Data Frames to 2 decimal places
pd.options.display.precision = 2

# Hide warning messages in notebook
import warnings
warnings.filterwarnings('ignore')

# print(x.strftime("%d""/""%m""/""%Y"))

from api_keys import api_key

# %%
url = "https://api.nasa.gov/neo/rest/v1/feed?"

# https://api.nasa.gov/neo/rest/v1/feed?start_date=START_DATE&end_date=END_DATE&api_key=API_KEY

# %%
days365=pd.Series(pd.date_range('2019', freq='D', periods=365)).dt.strftime("%Y-%m-%d")
days365
# Out:
# 0      2019-01-01
# 1      2019-01-02
# 2      2019-01-03
# 3      2019-01-04
# 4      2019-01-05
#           ...
# 360    2019-12-27
# 361    2019-12-28
# 362    2019-12-29
# 363    2019-12-30
# 364    2019-12-31
# Length: 365, dtype: object

# %%
start = []
end = []

from datetime import date, timedelta

sdate = date(2019, 1, 1)   # start date
edate = date(2019, 12, 31)   # end date
delta = edate - sdate       # as timedelta


for i in range(int((delta.days)+1)):
    sday = sdate + timedelta(days=i)
    eday = sday + timedelta(days=1)
    if eday > edate:
        eday=edate
    start.append(sday)
    end.append(eday)
    
end = start

# %%
my_list=dates
  
# How many elements each 
# list should have 
n = 7 
  
# using list comprehension 
final = [my_list[i * n:(i + 1) * n] for i in range((len(my_list) + n - 1) // n )]  
final
# x=0
# y=364
# for dates in range(x,y,7):
#     x=dates
#     print(dates[x:x+7])
# Out:
# [0   2019-01-01
#  1   2019-01-02
#  2   2019-01-03
#  3   2019-01-04
#  4   2019-01-05
#  5   2019-01-06
#  6   2019-01-07
#  dtype: datetime64[ns],
#  7    2019-01-08
#  8    2019-01-09
#  9    2019-01-10
#  10   2019-01-11
#  11   2019-01-12
#  12   2019-01-13
#  13   2019-01-14
#  dtype: datetime64[ns],
#  14   2019-01-15
#  15   2019-01-16
#  16   2019-01-17
#  17   2019-01-18
#  18   2019-01-19
#  19   2019-01-20
#  20   2019-01-21
#  dtype: datetime64[ns],
#  21   2019-01-22
#  22   2019-01-23
#  23   2019-01-24
#  24   2019-01-25
#  25   2019-01-26
#  26   2019-01-27
#  27   2019-01-28
#  dtype: datetime64[ns],
#  28   2019-01-29
#  29   2019-01-30
#  30   2019-01-31
#  31   2019-02-01
#  32   2019-02-02
#  33   2019-02-03
#  34   2019-02-04
#  dtype: datetime64[ns],
#  35   2019-02-05
#  36   2019-02-06
#  37   2019-02-07
#  38   2019-02-08
#  39   2019-02-09
#  40   2019-02-10
#  41   2019-02-11
#  dtype: datetime64[ns],
#  42   2019-02-12
#  43   2019-02-13
# ...

# %%
start_end = {"Start Date":start, "End Date":end}
date_df = pd.DataFrame(start_end)
date_df
# Out:
#      Start Date    End Date
# 0    2019-01-01  2019-01-01
# 1    2019-01-02  2019-01-02
# 2    2019-01-03  2019-01-03
# 3    2019-01-04  2019-01-04
# 4    2019-01-05  2019-01-05
# ..          ...         ...
# 360  2019-12-27  2019-12-27
# 361  2019-12-28  2019-12-28
# 362  2019-12-29  2019-12-29
# 363  2019-12-30  2019-12-30
# 364  2019-12-31  2019-12-31
#
# [365 rows x 2 columns]

# %%
response["near_earth_objects"]
# Out:
# {'2019-01-07': [{'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/2512245?api_key=QeO3Z7069osFdDe8dMJnF0UKWc7rUZNHHAubv55C'},
#    'id': '2512245',
#    'neo_reference_id': '2512245',
#    'name': '512245 (2016 AU8)',
#    'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2512245',
#    'absolute_magnitude_h': 19.9,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.2783267681,
#      'estimated_diameter_max': 0.6223575734},
#     'meters': {'estimated_diameter_min': 278.3267680719,
#      'estimated_diameter_max': 622.3575733667},
#     'miles': {'estimated_diameter_min': 0.1729441822,
#      'estimated_diameter_max': 0.3867149477},
#     'feet': {'estimated_diameter_min': 913.1455937611,
#      'estimated_diameter_max': 2041.8556210042}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2019-01-07',
#      'close_approach_date_full': '2019-Jan-07 23:17',
# ...

# %%
# numbers = [1, 2, 3]
# letters = ["A", "B", "C"]

# for numbers_value, letters_value in zip(numbers, letters):
#     print(numbers_value, letters_value)

# %%
# Make 52 API calls to NASA to pull JSON files for each set of dates
# for i in range(len(start)):
#     url = f"https://api.nasa.gov/neo/rest/v1/feed?start_date={str(start[i])}&end_date={str(end[i])}&api_key={api_key}"
#     print(url)
#     response=requests.get(url).json()


# asteriod_id=[]
# name=[]
# date=[]
# absolute_magnitude_h=[]
# diameter_max_km = []
# diameter_min_km =[]
# diameter_min_km = []
# is_potentially_hazardous_asteroid=[]
# miss_distance_km = []
# orbiting_body =[]
# asterioddate = []

# # for i in range(len(start)):
#     url = f"https://api.nasa.gov/neo/rest/v1/feed?start_date={str(start[i])}&end_date={str(end[i])}&api_key={api_key}"
# #     url = f"https://api.nasa.gov/neo/rest/v1/feed?start_date=2019-01-01&end_date=2019-01-01&api_key={api_key}"
# #     print(url)
#     response=requests.get(url).json()

# #     name.append(response["near_earth_objects"][(str(start[i]))][0]['name'])
#     for day in days365:
    
# #     date.append(str(start[i]))

#     asterioddate.append(str(start[i]))
#     asteriod_id.append(response["near_earth_objects"][(str(start[i]))][0]['id'])
#     name.append(response["near_earth_objects"][(str(start[i]))][0]['name'])
#     absolute_magnitude_h.append(response["near_earth_objects"][(str(start[i]))][0]['absolute_magnitude_h'])
#     diameter_max_km.append(response["near_earth_objects"][(str(start[i]))][0]['estimated_diameter']['kilometers']['estimated_diameter_max'])
#     diameter_min_km.append(response["near_earth_objects"][(str(start[i]))][0]['estimated_diameter']['kilometers']['estimated_diameter_min'])
#     is_potentially_hazardous_asteroid.append(response["near_earth_objects"][(str(start[i]))][0]['is_potentially_hazardous_asteroid'])
#     miss_distance_km.append(response["near_earth_objects"][(str(start[i]))][0]['close_approach_data'][0]['miss_distance']['kilometers'])
#     orbiting_body.append(response["near_earth_objects"][(str(start[i]))][0]['close_approach_data'][0]['orbiting_body'])

# %%
asteriod_id=[]
name=[]
date=[]
absolute_magnitude_h=[]
diameter_max_km = []
diameter_min_km =[]
diameter_min_km = []
is_potentially_hazardous_asteroid=[]
miss_distance_km = []
orbiting_body =[]
asterioddate = []
date= ["2019-01-01", "2019-01-02", "2019-01-03", "2019-01-04"]

# for i in range(len(start)):
    
#     url = f"https://api.nasa.gov/neo/rest/v1/feed?start_date=2019-01-01&end_date=2019-01-01&api_key={api_key}"
#     print(url)
    

#     name.append(response["near_earth_objects"][(str(start[i]))][0]['name'])
for day in date:
    url = f"https://api.nasa.gov/neo/rest/v1/feed?start_date={day}&end_date={day}&api_key={api_key}"
    response=requests.get(url).json()
        
    asterioddate.append(day)
    asteriod_id.append(response["near_earth_objects"][{day}][0]['id'])
#     name.append(response["near_earth_objects"][(str(start[i]))][0]['name'])
#     absolute_magnitude_h.append(response["near_earth_objects"][(str(start[i]))][0]['absolute_magnitude_h'])
#     diameter_max_km.append(response["near_earth_objects"][(str(start[i]))][0]['estimated_diameter']['kilometers']['estimated_diameter_max'])
#     diameter_min_km.append(response["near_earth_objects"][(str(start[i]))][0]['estimated_diameter']['kilometers']['estimated_diameter_min'])
#     is_potentially_hazardous_asteroid.append(response["near_earth_objects"][(str(start[i]))][0]['is_potentially_hazardous_asteroid'])
#     miss_distance_km.append(response["near_earth_objects"][(str(start[i]))][0]['close_approach_data'][0]['miss_distance']['kilometers'])
#     orbiting_body.append(response["near_earth_objects"][(str(start[i]))][0]['close_approach_data'][0]['orbiting_body'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-985308985a31> in <module>
#      24
#      25     asterioddate.append(day)
# ---> 26     asteriod_id.append(response["near_earth_objects"][(str(start[i]))][0]['id'])
#      27     name.append(response["near_earth_objects"][(str(start[i]))][0]['name'])
#      28     absolute_magnitude_h.append(response["near_earth_objects"][(str(start[i]))][0]['absolute_magnitude_h'])
#
# KeyError: '2019-12-31'

# %%
for day in date:
    url = f"https://api.nasa.gov/neo/rest/v1/feed?start_date={day}&end_date={day}&api_key={api_key}"
    response=requests.get(url).json()
        
    asterioddate.append(day)

# %%
# response = requests.get(query_url).json()
pprint(response)

# %%
asterioddate
# Out:
# ['2019-01-01', '2019-01-01', '2019-01-02', '2019-01-03', '2019-01-04']

# %%
df = pd.DataFrame({"Date": asterioddate, "ID":asteriod_id, "Name": name, "Absolute Magnitude": absolute_magnitude_h, "Estimated Max Diameter": diameter_max_km, "Estimated Min Diameter": diameter_min_km, "Potentially Hazardous?": is_potentially_hazardous_asteroid, "Miss Distance (km)": miss_distance_km, "Orbiting Body": orbiting_body})
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: (0, 0)
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-3474cc35aa50> in <module>
#       1 a=0
#       2 b=7
# ...

# %%
id=[]
name=[]
date=[]
absolute_magnitude_h=[]
diameter_max_km = []
diameter_min_km =[]
diameter_min_km = []
is_potentially_hazardous_asteroid=[]
miss_distance_km = []
orbiting_body =[]

START_DATE=["2019-01-01","2019-01-08", "2019-01-15"] 
END_DATE=["2019-01-07", "2019-01-014" "2019-01-20"]
# START_DATE=date
# END_DATE=START_DATE+7

for date in DATES: 
    url_1=(f"https://api.nasa.gov/neo/rest/v1/feed?start_date={DATE[0]}&end_date={DATE[1]}&api_key={api_key}")
    response=requests.get(url_1).json()
    

date.append(date)
id.append(response["near_earth_objects"]['2020-07-16'][0]['id'])

name.append(response["near_earth_objects"]['2020-07-16'][0]['name'])

absolute_magnitude_h.append(response["near_earth_objects"]['2020-07-16'][0]['absolute_magnitude_h'])

diameter_max_km.append(response["near_earth_objects"]['2020-07-16'][0]['estimated_diameter']['kilometers']['estimated_diameter_max'])

diameter_min_km.append(response["near_earth_objects"]['2020-07-16'][0]['estimated_diameter']['kilometers']['estimated_diameter_min'])

is_potentially_hazardous_asteroid.append(response["near_earth_objects"]['2020-07-16'][0]['is_potentially_hazardous_asteroid'])

miss_distance_km.append(response["near_earth_objects"]['2020-07-16'][0]['close_approach_data'][0]['miss_distance']['kilometers'])

orbiting_body.append(response["near_earth_objects"]['2020-07-16'][0]['close_approach_data'][0]['orbiting_body'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-57ee5d6ae583> in <module>
#      15 # END_DATE=START_DATE+7
#      16
# ---> 17 for date in DATES:
#      18     url_1=(f"https://api.nasa.gov/neo/rest/v1/feed?start_date={DATE[0]}&end_date={DATE[1]}&api_key={api_key}")
#      19     response=requests.get(url_1).json()
#
# NameError: name 'DATES' is not defined

# %%
days365=pd.Series(pd.date_range('2019', freq='D', periods=365)).dt.strftime("%Y-%m-%d")
days365
# Out:
# 0      2019-01-01
# 1      2019-01-02
# 2      2019-01-03
# 3      2019-01-04
# 4      2019-01-05
#           ...
# 360    2019-12-27
# 361    2019-12-28
# 362    2019-12-29
# 363    2019-12-30
# 364    2019-12-31
# Length: 365, dtype: object

# %%
DAYS= []
for days in days365:
    DAYS.append(str(days))
print(DAYS)
# Out:
# ['2019-01-01', '2019-01-02', '2019-01-03', '2019-01-04', '2019-01-05', '2019-01-06', '2019-01-07', '2019-01-08', '2019-01-09', '2019-01-10', '2019-01-11', '2019-01-12', '2019-01-13', '2019-01-14', '2019-01-15', '2019-01-16', '2019-01-17', '2019-01-18', '2019-01-19', '2019-01-20', '2019-01-21', '2019-01-22', '2019-01-23', '2019-01-24', '2019-01-25', '2019-01-26', '2019-01-27', '2019-01-28', '2019-01-29', '2019-01-30', '2019-01-31', '2019-02-01', '2019-02-02', '2019-02-03', '2019-02-04', '2019-02-05', '2019-02-06', '2019-02-07', '2019-02-08', '2019-02-09', '2019-02-10', '2019-02-11', '2019-02-12', '2019-02-13', '2019-02-14', '2019-02-15', '2019-02-16', '2019-02-17', '2019-02-18', '2019-02-19', '2019-02-20', '2019-02-21', '2019-02-22', '2019-02-23', '2019-02-24', '2019-02-25', '2019-02-26', '2019-02-27', '2019-02-28', '2019-03-01', '2019-03-02', '2019-03-03', '2019-03-04', '2019-03-05', '2019-03-06', '2019-03-07', '2019-03-08', '2019-03-09', '2019-03-10', '2019-03-11', '2019-03-12', '20
# ...

# %%
# Import API key

 # Save config information.
url = "https://api.nasa.gov/neo/rest/v1/feed?"
# Build partial query URL
query_url = f"{url}&api_key={api_key}"
response = requests.get(query_url).json()
response["near_earth_objects"]

# %%
Sentry=response["near_earth_objects"]["2020-07-16"][0]["is_sentry_object"]
