# %%
import nasapy
import pandas as pd
import numpy as np
# import folium
# from folium.plugins import HeatMap
import matplotlib.pyplot as plt
import seaborn as sns

# Import API key
from api_keys import nasa_key

# %matplotlib inline

# %%
fb = nasapy.fireballs(date_min='2010-01-01', date_max='2019-12-31', return_df=True)

# %%
fb.dropna(inplace=True)

fb['lat'] = fb['lat'].astype(float)
fb['lon'] = fb['lon'].astype(float)
fb['energy'] = fb['energy'].astype(float)

# %%
fb.head()
# Out:
#                   date energy impact-e   lat lat-dir    lon lon-dir   alt  \
# 0  2010-01-15 19:17:54   49.2      1.2   8.3       S   27.0       E  25.0
# 1  2010-02-24 19:55:58    9.3     0.28   2.6       S  102.2       W  None
# 2  2010-02-26 22:46:13   23.7     0.65  37.3       S  166.0       W  None
# 3  2010-02-28 22:24:50   15.3     0.44  48.7       N   21.0       E  37.0
# 4  2010-03-08 22:02:07   32.3     0.85  32.0       N   92.9       W  52.0
#
#     vel
# 0  14.0
# 1  None
# 2  None
# 3  15.1
# 4  24.5

# %%
dir(nasapy.Nasa)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'api_key',
#  'asteroid_feed',
#  'coronal_mass_ejection',
#  'earth_assets',
#  'earth_imagery',
#  'epic',
#  'genelab_search',
#  'geomagnetic_storm',
#  'get_asteroids',
#  'hight_speed_stream',
#  'interplantary_shock',
#  'limit_remaining',
#  'magnetopause_crossing',
#  'mars_rover',
#  'mars_weather',
#  'mars_weather_limit_remaining',
#  'picture_of_the_day',
#  'radiation_belt_enhancement',
#  'solar_energetic_particle',
#  'solar_flare',
#  'techport',
#  'wsa_enlil_simulation']

# %%
? nasapy.Nasa.api_key
# Out:
# Type:        property
# String form: <property object at 0x000001588E0F9688>
# Docstring:   <no docstring>

# %%
dir(nasapy.api)
# Out:
# ['DataFrame',
#  'Nasa',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_check_dates',
#  '_donki_request',
#  '_media_assets',
#  '_return_api_result',
#  'close_approach',
#  'datetime',
#  'exoplanets',
#  'fireballs',
#  'julian_date',
#  'media_asset_captions',
#  'media_asset_manifest',
#  'media_asset_metadata',
#  'media_search',
#  'mission_design',
#  'nhats',
#  'requests',
#  'scout',
#  'sentry',
#  'tle',
#  'urljoin']

# %%
nasapy.close_approach(date_min='2010-01-01')
# Out:
# {'signature': {'source': 'NASA/JPL SBDB Close Approach Data API',
#   'version': '1.1'},
#  'count': '6912',
#  'fields': ['des',
#   'orbit_id',
#   'jd',
#   'cd',
#   'dist',
#   'dist_min',
#   'dist_max',
#   'v_rel',
#   'v_inf',
#   't_sigma_f',
#   'h'],
#  'data': [['2010 AE3',
#    '11',
#    '2455199.255165645',
#    '2010-Jan-02 18:07',
#    '0.0420116134655199',
#    '0.0417063005660389',
#    '0.0423169234587294',
#    '13.8757614310003',
#    '13.8711899415874',
#    '< 00:01',
#    '23.7'],
#   ['2010 AF',
#    '8',
#    '2455200.158267497',
#    '2010-Jan-03 15:48',
#    '0.0310103799033046',
#    '0.0307764015929949',
#    '0.0312443938140407',
#    '14.5106344280196',
#    '14.5047118947768',
#    '00:01',
#    '25.0'],
#   ['2010 AJ3',
#    '10',
#    '2455204.369196604',
#    '2010-Jan-07 20:52',
#    '0.0259255255836512',
#    '0.0258655485485462',
#    '0.0259855022147426',
#    '11.7199630991549',
#    '11.7111906449605',
#    '< 00:01',
#    '24.5'],
# ...

# %%
dir(nasapy.Nasa)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'api_key',
#  'asteroid_feed',
#  'coronal_mass_ejection',
#  'earth_assets',
#  'earth_imagery',
#  'epic',
#  'genelab_search',
#  'geomagnetic_storm',
#  'get_asteroids',
#  'hight_speed_stream',
#  'interplantary_shock',
#  'limit_remaining',
#  'magnetopause_crossing',
#  'mars_rover',
#  'mars_weather',
#  'mars_weather_limit_remaining',
#  'picture_of_the_day',
#  'radiation_belt_enhancement',
#  'solar_energetic_particle',
#  'solar_flare',
#  'techport',
#  'wsa_enlil_simulation']

# %%
neos = nasapy.close_approach(date_min='2010-01-01', date_max='2019-12-31', return_df=False)

# %%
? nasapy.Nasa.get_asteroids
# Out:
# Signature:  nasapy.Nasa.get_asteroids(self, asteroid_id=None)
# Docstring:
# Returns data from the overall asteroid data-set or specific asteroids given an ID.
#
# Parameters
# ----------
# asteroid_id : str, int, default None
#     If None, the entire asteroid data set is returned. If an :code:`asteroid_id` is provided, data on that
#     specific asteroid is returned.
#
# Raises
# ------
# HTTPError:
#     Raised if the returned status code from the API is not 200 (success).
#
# Returns
# -------
# dict
#     Dictionary object representing the returned JSON data from the NASA API.
#
# Examples
# --------
# # Initialize NASA API with a demo key.
# >>> n = Nasa()
# # Get entire asteroid data set.
# >>> n.get_asteroids()
# # Get asteroid with ID 3542519
# >>> n.get_asteroids(asteroid_id=3542519)
#
# Notes
# -----
# All the data is from the NASA JPL Asteroid team (http://neo.jpl.nasa.gov/). The API is maintained by the
# `SpaceRocks team <https://github.com/SpaceRocks/>`_
# ...

# %%
nasapy.Nasa.get_asteroids()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-7fa37247b3df> in <module>
# ----> 1 nasapy.Nasa.get_asteroids()
#
# TypeError: get_asteroids() missing 1 required positional argument: 'self'

# %%
neos
# Out:
# {'signature': {'source': 'NASA/JPL SBDB Close Approach Data API',
#   'version': '1.1'},
#  'count': '6203',
#  'fields': ['des',
#   'orbit_id',
#   'jd',
#   'cd',
#   'dist',
#   'dist_min',
#   'dist_max',
#   'v_rel',
#   'v_inf',
#   't_sigma_f',
#   'h'],
#  'data': [['2010 AE3',
#    '11',
#    '2455199.255165645',
#    '2010-Jan-02 18:07',
#    '0.0420116134655199',
#    '0.0417063005660389',
#    '0.0423169234587294',
#    '13.8757614310003',
#    '13.8711899415874',
#    '< 00:01',
#    '23.7'],
#   ['2010 AF',
#    '8',
#    '2455200.158267497',
#    '2010-Jan-03 15:48',
#    '0.0310103799033046',
#    '0.0307764015929949',
#    '0.0312443938140407',
#    '14.5106344280196',
#    '14.5047118947768',
#    '00:01',
#    '25.0'],
#   ['2010 AJ3',
#    '10',
#    '2455204.369196604',
#    '2010-Jan-07 20:52',
#    '0.0259255255836512',
#    '0.0258655485485462',
#    '0.0259855022147426',
#    '11.7199630991549',
#    '11.7111906449605',
#    '< 00:01',
#    '24.5'],
# ...

# %%
neos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6203 entries, 0 to 6202
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   des        6203 non-null   object
#  1   orbit_id   6203 non-null   object
#  2   jd         6203 non-null   object
#  3   cd         6203 non-null   object
#  4   dist       6203 non-null   object
#  5   dist_min   6203 non-null   object
#  6   dist_max   6203 non-null   object
#  7   v_rel      6203 non-null   object
#  8   v_inf      6198 non-null   object
#  9   t_sigma_f  6203 non-null   object
#  10  h          6201 non-null   object
# dtypes: object(11)
# memory usage: 533.2+ KB

# %%
# Initialize the NASA API with a demo key.
n = NASA(key=api_keys)
# Get asteroids approaching Earth at the beginning of 2019.
nasapy.Nasa.get_asteroids()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-e7571462ae11> in <module>
#       1 # Initialize the NASA API with a demo key.
# ----> 2 n = NASA(key=api_keys)
#       3 # Get asteroids approaching Earth at the beginning of 2019.
#       4 nasapy.Nasa.get_asteroids()
#
# NameError: name 'NASA' is not defined

# %%
nasa = Nasa(key=key)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-9a50ebd46370> in <module>
# ----> 1 nasa = Nasa(key=key)
#
# NameError: name 'Nasa' is not defined

# %%
# Get entire asteroid data set.
nasa.get_asteroids()
# Get asteroid with ID 3542519
nasa.get_asteroids(asteroid_id=3542519)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-b1b2a61c77c6> in <module>
#       1 # Get entire asteroid data set.
# ----> 2 nasa.get_asteroids()
#       3 # Get asteroid with ID 3542519
#       4 nasa.get_asteroids(asteroid_id=3542519)
#
# NameError: name 'nasa' is not defined

# %%
# Return today's picture of the day
nasa.picture_of_the_day()
# Return a previous date's picture of the day with the high-definition URL included.
nasa.picture_of_the_day('2019-01-01', hd=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-9771b513eb40> in <module>
#       1 # Return today's picture of the day
# ----> 2 nasa.picture_of_the_day()
#       3 # Return a previous date's picture of the day with the high-definition URL included.
#       4 nasa.picture_of_the_day('2019-01-01', hd=True)
#
# NameError: name 'nasa' is not defined

# %%
  def asteroid_feed(start_date, end_date):

        url = 'https://api.nasa.gov/neo/rest/v1/feed'

#         start_date, end_date = _check_dates(start_date=start_date, end_date=end_date)

        r = requests.get(url,
                         params={
                             'api_key': api_key,
                             'start_date': start_date,
                             'end_date': end_date,
                             'ID': asteroid_id
                         })

        if r.status_code != 200:
            raise requests.exceptions.HTTPError(r.reason, r.url)

        else:
            self.__limit_remaining = r.headers['X-RateLimit-Remaining']
            return r.json()
